# %%
# !pip install datasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in /home/gustavokpc/.local/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: numpy>=1.17 in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (12.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/lib/python3/dist-packages (from datasets) (2.25.1)
# Requirement already satisfied: tqdm>=4.62.1 in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec>=2021.11.1 in /home/gustavokpc/.local/lib/python3.10/site-packages (from fsspec[http]>=2021.11.1->datasets) (2023.5.0)
# Requirement already satisfied: aiohttp in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (0.17.3)
# Requirement already satisfied: packaging in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (23.1)
# Requirement already satisfied: responses<0.19 in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from datasets) (5.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /home/gustavokpc/.local/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/gustavokpc/.local/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.6.3)
# Requirement already satisfied: urllib3>=1.25.10 in /usr/lib/python3/dist-packages (from responses<0.19->datasets) (1.26.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gustavokpc/.local/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/gustavokpc/.local/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp->datasets) (3.3)
#
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
pip install transformers datasets evaluate
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/gustavokpc/.local/lib/python3.10/site-packages (4.34.1)
# Requirement already satisfied: datasets in /home/gustavokpc/.local/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: evaluate in /home/gustavokpc/.local/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: filelock in /home/gustavokpc/.local/lib/python3.10/site-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/gustavokpc/.local/lib/python3.10/site-packages (from transformers) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /home/gustavokpc/.local/lib/python3.10/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/gustavokpc/.local/lib/python3.10/site-packages (from transformers) (2023.10.3)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /home/gustavokpc/.local/lib/python3.10/site-packages (from transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /home/gustavokpc/.local/lib/python3.10/site-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /home/gustavokpc/.local/lib/python3.10/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (12.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: xxhash in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec>=2021.11.1 in /home/gustavokpc/.local/lib/python3.10/site-packages (from fsspec[http]>=2021.11.1->datasets) (2023.5.0)
# Requirement already satisfied: aiohttp in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (3.8.4)
# Requirement already satisfied: responses<0.19 in /home/gustavokpc/.local/lib/python3.10/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/gustavokpc/.local/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/gustavokpc/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.6.3)
# Requirement already satisfied: urllib3>=1.25.10 in /usr/lib/python3/dist-packages (from responses<0.19->datasets) (1.26.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gustavokpc/.local/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/gustavokpc/.local/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp->datasets) (3.3)
#
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in /home/gustavokpc/.local/lib/python3.10/site-packages (8.1.1)
# Requirement already satisfied: comm>=0.1.3 in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipywidgets) (0.1.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipywidgets) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipywidgets) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipywidgets) (3.0.9)
# Requirement already satisfied: backcall in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /home/gustavokpc/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in /home/gustavokpc/.local/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/gustavokpc/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /home/gustavokpc/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
#
# [notice] A new release of pip is available: 23.3 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from datasets import load_dataset, Dataset
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, matthews_corrcoef
from transformers.keras_callbacks import PushToHubCallback
from huggingface_hub import notebook_login

from transformers import AutoTokenizer
from transformers import DataCollatorWithPadding
import evaluate
from transformers import create_optimizer
import tensorflow as tf
from transformers import TFAutoModelForSequenceClassification
from transformers.keras_callbacks import KerasMetricCallback
# Out:
# 2023-11-25 02:47:07.523637: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-25 02:47:07.524970: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-25 02:47:07.550638: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-25 02:47:07.551146: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-25 02:47:08.040377: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
tokenizer = AutoTokenizer.from_pretrained("bert-large-uncased")

# %%
dataframe_completo = pd.read_csv("out.csv")
ds_completo = Dataset.from_pandas(dataframe_completo)
ds_completo
# Out:
# Dataset({
#     features: ['source', 'question', 'answer', 'context', 'language', 'label'],
#     num_rows: 15164
# })

# %%
y = dataframe_completo.loc[:,"label"]
X = dataframe_completo.loc[:,"question"]

# %%
X_train, X_to_split, y_train, y_to_split = train_test_split(X, y, test_size=0.2, random_state=7, stratify=y)

# %%
X_validation, X_test, y_validation, y_test = train_test_split(X_to_split, y_to_split, test_size=0.5, random_state=7, stratify=y_to_split)

# %%
train_df = pd.concat([X_train, y_train], axis=1)
validation_df = pd.concat([X_validation, y_validation], axis=1)
test_df = pd.concat([X_test, y_test], axis=1)

# %%
train_df
# Out:
#                                                 question  label
# 2404   Qual o dano nas algas está sendo causado pelo ...    1.0
# 12654       Em que setor os empregos começam a diminuir?    0.0
# 13630  Quando foi estabelecida a Direção da Bibliotec...    0.0
# 2560   Em quais as áreas é esperado que o ruído antro...    1.0
# 4582   Qual foi o tamanho da população da ilha de São...    1.0
# ...                                                  ...    ...
# 7108    O Parque Nacional Monte Pascoal Ã© em qual bioma    0.0
# 10031        Que tipo de floresta Ã© a selva amazÃ´nica?    0.0
# 12231  Quantos colonos originais se estabeleceram em ...    0.0
# 379       Onde as pinças de Mithraculis foram coletadas?    1.0
# 4897             Onde a noronha ela pode ser encontrada?    1.0
#
# [12131 rows x 2 columns]

# %%
train_ds = Dataset.from_pandas(train_df)
validation_ds = Dataset.from_pandas(validation_df)
test_ds = Dataset.from_pandas(test_df)

# %%
train_ds
# Out:
# Dataset({
#     features: ['question', 'label', '__index_level_0__'],
#     num_rows: 12131
# })

# %%
def preprocess_function(examples):
    return tokenizer(examples["question"], truncation=True)

# %%
tokenized_train_ds = train_ds.map(preprocess_function, batched=True)
tekenized_validation_ds = validation_ds.map(preprocess_function, batched=True)
tokenized_test_ds = test_ds.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/12131 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1516 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1517 [00:00<?, ? examples/s]

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, return_tensors="tf")

# %%
accuracy = evaluate.load("accuracy")

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

# %%
id2label = {0: "NEGATIVE", 1: "POSITIVE"}
label2id = {"NEGATIVE": 0, "POSITIVE": 1}

# %%
batch_size = 16
num_epochs = 5
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=2e-5, num_warmup_steps=0, num_train_steps=total_train_steps)
# Out:
# 2023-10-24 10:44:10.575975: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-24 10:44:10.576378: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model = TFAutoModelForSequenceClassification.from_pretrained(
    "bert-base-uncased", num_labels=2, id2label=id2label, label2id=label2id
)
tf_train_set = model.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set = model.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_primeiro",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.fit(x=tf_train_set, validation_data=tf_validation_set, epochs=num_epochs, callbacks=callbacks)
# Out:
# Epoch 1/5
# 758/758 [==============================] - 1484s 2s/step - loss: 0.4152 - val_loss: 0.2564 - accuracy: 0.8879
# Epoch 2/5
# 758/758 [==============================] - 1288s 2s/step - loss: 0.2037 - val_loss: 0.2408 - accuracy: 0.9030
# Epoch 3/5
# 758/758 [==============================] - 1252s 2s/step - loss: 0.1277 - val_loss: 0.1965 - accuracy: 0.9274
# Epoch 4/5
# 758/758 [==============================] - 1256s 2s/step - loss: 0.0777 - val_loss: 0.2381 - accuracy: 0.9255
# Epoch 5/5
# 758/758 [==============================] - 1213s 2s/step - loss: 0.0491 - val_loss: 0.2583 - accuracy: 0.9274

# %%
batch_size = 16
num_epochs = 3
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=5e-5, num_warmup_steps=0, num_train_steps=total_train_steps)

# %%
model2 = TFAutoModelForSequenceClassification.from_pretrained(
    "bert-base-uncased", num_labels=2, id2label=id2label, label2id=label2id
)

tf_train_set2 = model2.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set2 = model2.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model2.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set2)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_segundo",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# c:\Users\gusta\Documents\IC\IC_segundo is already a clone of https://huggingface.co/gustavokpc/IC_segundo. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
model2.fit(x=tf_train_set2, validation_data=tf_validation_set2, epochs=num_epochs, callbacks=callbacks)
# Out:
# Epoch 1/3
# 758/758 [==============================] - 1217s 2s/step - loss: 0.3384 - val_loss: 0.2146 - accuracy: 0.9195
# Epoch 2/3
# 758/758 [==============================] - 1188s 2s/step - loss: 0.1693 - val_loss: 0.2000 - accuracy: 0.9235
# Epoch 3/3
# 758/758 [==============================] - 1187s 2s/step - loss: 0.0909 - val_loss: 0.2104 - accuracy: 0.9281

# %%
batch_size = 16
num_epochs = 3
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=3e-5, num_warmup_steps=0, num_train_steps=total_train_steps)

# %%
model3 = TFAutoModelForSequenceClassification.from_pretrained(
    "bert-base-uncased", num_labels=2, id2label=id2label, label2id=label2id
)

tf_train_set3 = model3.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set3 = model3.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model3.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set3)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_terceiro",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Cloning https://huggingface.co/gustavokpc/IC_terceiro into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/gustavokpc/IC_terceiro into local empty directory.

# %%
model3.fit(x=tf_train_set3, validation_data=tf_validation_set3, epochs=num_epochs, callbacks=callbacks)
# Out:
# Epoch 1/3
# 758/758 [==============================] - 1183s 2s/step - loss: 0.3406 - val_loss: 0.2337 - accuracy: 0.9037
# Epoch 2/3
# 758/758 [==============================] - 1205s 2s/step - loss: 0.1737 - val_loss: 0.2312 - accuracy: 0.9142
# Epoch 3/3
# 758/758 [==============================] - 1241s 2s/step - loss: 0.1000 - val_loss: 0.2233 - accuracy: 0.9261

# %%
batch_size = 16
num_epochs = 3
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=2e-5, num_warmup_steps=0, num_train_steps=total_train_steps)

# %%
model4 = TFAutoModelForSequenceClassification.from_pretrained(
    "bert-base-uncased", num_labels=2, id2label=id2label, label2id=label2id
)

tf_train_set4 = model4.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set4 = model4.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model4.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set4)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_quarto",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# c:\Users\gusta\Documents\IC\IC_quarto is already a clone of https://huggingface.co/gustavokpc/IC_quarto. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:c:\Users\gusta\Documents\IC\IC_quarto is already a clone of https://huggingface.co/gustavokpc/IC_quarto. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
model4.fit(x=tf_train_set4, validation_data=tf_validation_set4, epochs=num_epochs, callbacks=callbacks)
# Out:
# Epoch 1/3
# 758/758 [==============================] - 1449s 2s/step - loss: 0.3532 - val_loss: 0.2443 - accuracy: 0.8971
# Epoch 2/3
# 758/758 [==============================] - 1278s 2s/step - loss: 0.1794 - val_loss: 0.1957 - accuracy: 0.9255
# Epoch 3/3
# 758/758 [==============================] - 1358s 2s/step - loss: 0.1100 - val_loss: 0.2097 - accuracy: 0.9281

# %%
batch_size = 16
num_epochs = 3
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=1e-5, num_warmup_steps=0, num_train_steps=total_train_steps)

# %%
model5 = TFAutoModelForSequenceClassification.from_pretrained(
    "bert-base-uncased", num_labels=2, id2label=id2label, label2id=label2id
)

tf_train_set5 = model5.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set5 = model5.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model5.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set5)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_quinto",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Cloning https://huggingface.co/gustavokpc/IC_quinto into local empty directory.

# %%
model5.fit(x=tf_train_set5, validation_data=tf_validation_set5, epochs=num_epochs, callbacks=callbacks)
# Out:
# Epoch 1/3
# 758/758 [==============================] - 1414s 2s/step - loss: 0.3891 - val_loss: 0.2801 - accuracy: 0.8971
# Epoch 2/3
# 758/758 [==============================] - 1339s 2s/step - loss: 0.2242 - val_loss: 0.2510 - accuracy: 0.8991
# Epoch 3/3
# 758/758 [==============================] - 1370s 2s/step - loss: 0.1669 - val_loss: 0.2499 - accuracy: 0.9083

# %%
batch_size = 16
num_epochs = 5
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=2e-5, num_warmup_steps=0, num_train_steps=total_train_steps)

# %%
model6 = TFAutoModelForSequenceClassification.from_pretrained(
    "bert-large-uncased", num_labels=2, id2label=id2label, label2id=label2id
)

tf_train_set6 = model6.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set6 = model6.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model6.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set6)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_sexto",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# c:\Users\gusta\Documents\IC\IC_sexto is already a clone of https://huggingface.co/gustavokpc/IC_sexto. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
model6.fit(x=tf_train_set6, validation_data=tf_validation_set6, epochs=num_epochs, callbacks=callbacks)
# Out:
# Epoch 1/5
# 758/758 [==============================] - 3610s 5s/step - loss: 0.3840 - val_loss: 0.2265 - accuracy: 0.9057
# Epoch 2/5
# 758/758 [==============================] - 3609s 5s/step - loss: 0.2181 - val_loss: 0.2122 - accuracy: 0.9142
# Epoch 3/5
# 758/758 [==============================] - 3582s 5s/step - loss: 0.1492 - val_loss: 0.2082 - accuracy: 0.9215
# Epoch 4/5
# 758/758 [==============================] - 3598s 5s/step - loss: 0.1026 - val_loss: 0.1873 - accuracy: 0.9340
# Epoch 5/5
# 758/758 [==============================] - 3608s 5s/step - loss: 0.0695 - val_loss: 0.2067 - accuracy: 0.9321

# %%
batch_size = 16
num_epochs = 4
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=2e-5, num_warmup_steps=0, num_train_steps=total_train_steps)

# %%
model7 = TFAutoModelForSequenceClassification.from_pretrained(
    "bert-large-uncased", num_labels=2, id2label=id2label, label2id=label2id
)

tf_train_set7 = model7.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set7 = model7.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model7.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set7)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_setimo",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Cloning https://huggingface.co/gustavokpc/IC_setimo into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/gustavokpc/IC_setimo into local empty directory.

# %%
model7.fit(x=tf_train_set7, validation_data=tf_validation_set7, epochs=num_epochs, callbacks=callbacks)
# Out:
# Epoch 1/4
# 758/758 [==============================] - 3953s 5s/step - loss: 0.3694 - val_loss: 0.2526 - accuracy: 0.8832
# Epoch 2/4
# 758/758 [==============================] - 4004s 5s/step - loss: 0.1923 - val_loss: 0.2342 - accuracy: 0.9083
# Epoch 3/4
# 758/758 [==============================] - 3982s 5s/step - loss: 0.1188 - val_loss: 0.2038 - accuracy: 0.9228
# Epoch 4/4
# 758/758 [==============================] - 3852s 5s/step - loss: 0.0741 - val_loss: 0.2302 - accuracy: 0.9255

# %%
batch_size = 16
num_epochs = 3
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=2e-5, num_warmup_steps=0, num_train_steps=total_train_steps)

# %%
model8 = TFAutoModelForSequenceClassification.from_pretrained(
    "roberta-base", num_labels=2, id2label=id2label, label2id=label2id
)

tf_train_set8 = model8.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set8 = model8.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model8.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set8)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_oitavo",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaForSequenceClassification: ['roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Cloning https://huggingface.co/gustavokpc/IC_oitavo into local empty directory.

# %%
model8.fit(x=tf_train_set8, validation_data=tf_validation_set8, epochs=num_epochs, callbacks=callbacks)
# Out:
# Epoch 1/3
# 2023-10-24 10:57:31.698517: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [12131]
# 	 [[{{node Placeholder/_0}}]]
# 2023-10-24 10:57:31.698977: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [12131]
# 	 [[{{node Placeholder/_0}}]]
# 758/758 [==============================] - ETA: 0s - loss: 0.4793
# 2023-10-24 11:10:37.494533: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [1516]
# 	 [[{{node Placeholder/_0}}]]
# 2023-10-24 11:11:01.746055: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,48]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:03.327778: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:04.956494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:05.202046: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:05.415772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:05.629076: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:05.860500: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:06.104025: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:06.314070: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,34]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:06.506334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:06.751183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,29]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:06.923509: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:07.215718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,73]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:07.610060: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:07.815475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:08.094506: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:08.408372: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:08.592757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:08.805747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:09.005207: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:09.313801: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:09.537127: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:09.714031: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:09.989678: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:10.156782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:10.347186: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:10.603836: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:10.799640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:10.978884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:11.195175: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:11.439608: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:11.686303: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:11.962522: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:12.184542: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:12.449307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:12.662726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:12.866504: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:13.146704: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:13.432490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:13.663023: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:13.956962: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:14.134303: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:14.376275: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,55]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:14.692497: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:14.917191: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:15.151091: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,74]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:15.559210: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:15.768881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:16.018261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,77]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:16.419445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:16.672292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:16.847851: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:17.060299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:17.310370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:17.528900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:17.767125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:17.966765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:18.218284: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,109]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:18.804150: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:19.039624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,39]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:19.255780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:19.442527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:19.659438: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:19.866906: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:20.162097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,72]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:20.546074: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,84]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:20.988488: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:21.205951: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,47]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:21.467962: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,67]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:21.818414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:22.003295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:22.234415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:22.409858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:22.626726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:22.891044: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:23.100379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:23.413258: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:23.649465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:23.851989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:24.057981: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:24.282304: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:24.497341: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:24.733283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:24.939592: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:25.208937: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:25.395015: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:25.668350: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:25.864371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:26.077555: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:26.238109: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:26.429861: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:26.660158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:26.922715: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:27.243808: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,76]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:11:27.694135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [12,98]
# 	 [[{{node Placeholder/_2}}]]
# 758/758 [==============================] - 1065s 1s/step - loss: 0.4793 - val_loss: 0.3341 - accuracy: 0.8562
# Epoch 2/3
# 758/758 [==============================] - ETA: 0s - loss: 0.3030
# 2023-10-24 11:28:26.264404: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,48]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:26.528273: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:26.756147: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:27.021260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:27.253755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:27.458193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:27.683224: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:27.939361: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:28.158330: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,34]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:28.356182: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:28.584914: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,29]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:28.756840: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:29.047983: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,73]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:29.444159: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:29.648205: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:29.952080: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:30.250424: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:30.437337: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:30.645505: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:30.844971: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:31.161930: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:31.403910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:31.595738: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:31.888932: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:32.057614: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:32.255793: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:32.519151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:32.722923: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:32.910827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:33.134635: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:33.404820: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:33.664787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:33.964144: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:34.195662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:34.470108: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:34.701265: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:34.917366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:35.202510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:35.501789: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:28:35.733410: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# ...
# 2023-10-24 11:42:38.207286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:38.466513: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:38.644893: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:38.858136: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:39.121465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:39.346336: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:39.597378: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:39.801604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:40.054877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,109]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:40.666626: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:40.910704: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,39]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:41.141944: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:41.333721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:41.565603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:41.778551: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:42.082384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,72]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:42.488075: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,84]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:42.948537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:43.172777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,47]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:43.438819: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,67]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:43.801917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:43.990784: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:44.221428: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:44.401314: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:44.617672: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:44.889809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:45.106830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:45.415706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:45.643018: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:45.851351: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:46.054732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:46.292279: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:46.512852: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:46.747553: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:46.954192: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:47.215914: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:47.399047: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:47.653290: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:47.837396: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:48.065380: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:48.240595: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:48.416618: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:48.637882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:48.881175: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:49.183726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,76]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 11:42:49.611037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [12,98]
# 	 [[{{node Placeholder/_2}}]]
# Several commits (3) will be pushed upstream.
# 758/758 [==============================] - 839s 1s/step - loss: 0.2262 - val_loss: 0.2727 - accuracy: 0.8925

# %%
batch_size = 16
num_epochs = 5
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=2e-5, num_warmup_steps=0, num_train_steps=total_train_steps)

# %%
model9 = TFAutoModelForSequenceClassification.from_pretrained(
    "roberta-base", num_labels=2, id2label=id2label, label2id=label2id
)

tf_train_set9 = model9.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set9 = model9.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model9.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set9)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_nono",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFRobertaForSequenceClassification: ['roberta.embeddings.position_ids']
# - This IS expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFRobertaForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/gustavokpc/Documentos/IC/IC_nono is already a clone of https://huggingface.co/gustavokpc/IC_nono. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/home/gustavokpc/Documentos/IC/IC_nono is already a clone of https://huggingface.co/gustavokpc/IC_nono. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
model9.fit(x=tf_train_set9, validation_data=tf_validation_set9, epochs=num_epochs, callbacks=callbacks)
# Out:
# Epoch 1/5
# 2023-10-24 11:46:51.793429: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [12131]
# 	 [[{{node Placeholder/_0}}]]
# 2023-10-24 11:46:51.793762: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [12131]
# 	 [[{{node Placeholder/_0}}]]
# 758/758 [==============================] - ETA: 0s - loss: 0.4922
# 2023-10-24 11:59:38.627412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [1516]
# 	 [[{{node Placeholder/_0}}]]
# 2023-10-24 12:00:03.026325: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,48]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:04.646048: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:06.965327: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:07.195893: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:07.401605: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:07.609180: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:07.829431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:08.070976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:08.272282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,34]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:08.463866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:08.689443: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,29]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:08.854308: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:09.141722: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,73]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:09.534830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:09.726593: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:10.006132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:10.307426: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:10.486774: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:10.693743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:10.880262: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:11.186116: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:11.409347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:11.589673: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:11.869285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:12.026475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:12.219116: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:12.473733: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:12.663409: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:12.833972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:13.040928: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:13.282463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:13.517994: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:13.810826: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:14.028663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:14.296336: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:14.510381: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:14.713711: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:15.001645: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:15.289549: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:15.514534: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:15.826209: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:15.985371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:16.212323: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,55]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:16.516587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:16.742635: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:16.966768: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,74]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:17.363348: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:17.572580: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:17.827472: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,77]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:18.243239: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:18.498782: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:18.683469: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:18.889324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:19.150799: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:19.362149: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:19.607519: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:19.825211: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:20.088702: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,109]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:20.704621: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:20.925231: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,39]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:21.141386: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:21.326492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:21.561226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:21.772317: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:22.063063: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,72]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:22.440432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,84]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:22.894523: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:23.115835: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,47]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:23.374826: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,67]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:23.751590: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:23.938064: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:24.169092: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:24.344224: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:24.558233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:24.835881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:25.046081: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:25.372512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:25.613130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:25.824204: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:26.030839: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:26.261233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:26.487294: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:26.726713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:26.933208: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:27.211892: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:27.408439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:27.654788: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:27.854311: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:28.072152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:28.229835: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:28.413281: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:28.634627: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:28.889390: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:29.199111: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,76]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:00:29.598434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [12,98]
# 	 [[{{node Placeholder/_2}}]]
# 758/758 [==============================] - 825s 1s/step - loss: 0.4922 - val_loss: 0.3637 - accuracy: 0.8509
# Epoch 2/5
# 758/758 [==============================] - ETA: 0s - loss: 0.3328
# 2023-10-24 12:13:38.359872: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,48]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:38.622669: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:38.866026: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:39.126363: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:39.347955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:39.554478: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:39.782540: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:40.034750: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:40.257469: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,34]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:40.460904: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:40.691590: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,29]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:40.867968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:41.156655: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,73]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:41.558828: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:41.765346: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:42.052709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:42.353440: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:42.542973: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:42.753766: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:42.944036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:43.263430: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:43.496829: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:43.677393: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:43.959858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:44.124321: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:44.325141: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:44.587221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:44.785658: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:44.964066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:45.179265: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:45.432455: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:45.682418: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:45.967587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:46.207641: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:46.503534: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:46.721547: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:46.925217: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:47.221037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:47.515147: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:13:47.749079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# ...
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:45.880455: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:46.137940: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:46.311284: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:46.522300: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:46.783908: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:47.006407: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:47.254574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:47.450734: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:47.700732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,109]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:48.313776: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:48.546235: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,39]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:48.770619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:48.961311: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:49.190636: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:49.400947: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:49.690484: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,72]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:50.081721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,84]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:50.542194: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:50.759320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,47]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:51.018906: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,67]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:51.381196: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:51.560622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:51.790642: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:51.972402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:52.191916: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:52.468397: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:52.673773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:52.983136: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:53.205954: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:53.416687: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:53.613438: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:53.840887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:54.054666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:54.289603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:54.489611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:54.746228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:54.941890: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:55.188623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:55.371386: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:55.589736: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:55.758551: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:55.936953: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:56.147478: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:56.388202: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:56.695694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,76]
# 	 [[{{node Placeholder/_2}}]]
# 2023-10-24 12:54:57.105473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [12,98]
# 	 [[{{node Placeholder/_2}}]]
# 758/758 [==============================] - 816s 1s/step - loss: 0.1564 - val_loss: 0.2736 - accuracy: 0.8997

# %%
batch_size = 16
num_epochs = 7
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=1e-5, num_warmup_steps=0, num_train_steps=total_train_steps)
# Out:
# 2023-10-28 16:06:54.200220: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-28 16:06:54.200548: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model10 = TFAutoModelForSequenceClassification.from_pretrained(
    "bert-large-uncased", num_labels=2, id2label=id2label, label2id=label2id
)

tf_train_set10 = model10.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set10 = model10.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model10.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set10)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_10",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/gustavokpc/Documentos/IC/IC_10 is already a clone of https://huggingface.co/gustavokpc/IC_10. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
model10.fit(x=tf_train_set10, validation_data=tf_validation_set10, epochs=num_epochs, callbacks=callbacks)

# %%
batch_size = 16
num_epochs = 7
batches_per_epoch = len(X_train) // batch_size
total_train_steps = int(batches_per_epoch * num_epochs)
optimizer, schedule = create_optimizer(init_lr=5e-6, num_warmup_steps=0, num_train_steps=total_train_steps)
# Out:
# 2023-11-25 02:47:35.903927: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-25 02:47:35.904229: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model11 = TFAutoModelForSequenceClassification.from_pretrained(
    "bert-large-uncased", num_labels=2, id2label=id2label, label2id=label2id
)

tf_train_set11 = model11.prepare_tf_dataset(
    tokenized_train_ds,
    shuffle=True,
    batch_size=16,
    collate_fn=data_collator,
)

tf_validation_set11 = model11.prepare_tf_dataset(
    tekenized_validation_ds,
    shuffle=False,
    batch_size=16,
    collate_fn=data_collator,
)
model11.compile(optimizer=optimizer)  # No loss argument!
metric_callback = KerasMetricCallback(metric_fn=compute_metrics, eval_dataset=tf_validation_set11)
push_to_hub_callback = PushToHubCallback(
    output_dir="IC_11",
    tokenizer=tokenizer,
)
callbacks = [metric_callback, push_to_hub_callback]
# Out:
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /home/gustavokpc/Documentos/IC/IC_11 is already a clone of https://huggingface.co/gustavokpc/IC_11. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
model11.fit(x=tf_train_set11, validation_data=tf_validation_set11, epochs=num_epochs, callbacks=callbacks)
# Out:
# Epoch 1/7
# 2023-11-25 02:47:42.541936: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [12131]
# 	 [[{{node Placeholder/_0}}]]
# 2023-11-25 02:47:42.542278: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [12131]
# 	 [[{{node Placeholder/_0}}]]
# 758/758 [==============================] - ETA: 0s - loss: 0.4708
# 2023-11-25 03:27:30.911187: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int64 and shape [1516]
# 	 [[{{node Placeholder/_0}}]]
# 2023-11-25 03:28:50.350106: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,48]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:28:53.805191: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:28:58.555045: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:28:59.335004: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:00.019976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:00.670848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:01.382224: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:02.195274: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:02.868365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,34]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:03.496421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:04.305640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,29]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:04.863708: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:05.822385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,73]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:07.174811: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:07.835266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:08.805962: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:09.785798: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:10.374239: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:11.005361: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:11.599233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:12.646594: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:13.405760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:13.995688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:14.956840: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:15.477296: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:16.117915: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:16.976630: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:17.592348: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:18.137485: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:18.809787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:19.596112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:20.388953: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:21.292502: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:22.022385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:22.901473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:23.593022: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:24.230527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:25.168507: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:26.136238: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:26.869844: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:27.847049: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:28.384911: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:29.161607: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,55]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:30.165233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:30.901603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:31.659726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,74]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:33.013509: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:33.687445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:34.443316: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,77]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:35.850257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:36.674653: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:37.225359: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:37.863693: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:38.694299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:39.430857: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:40.247246: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:40.885764: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:41.701279: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,109]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:43.738863: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:44.515155: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,39]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:45.238059: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:45.815638: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:46.571052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:47.287221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:48.270802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,72]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:49.589750: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,84]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:51.157709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:51.866524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,47]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:52.728925: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,67]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:53.911522: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:54.524577: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:55.275062: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:55.836710: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:56.539122: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:57.416040: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:58.106039: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:59.195884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:29:59.936987: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:00.598830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:01.236002: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:01.977570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:02.680931: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:03.457216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:04.124674: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:04.971668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:05.541878: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:06.346068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:06.931660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:07.613468: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:08.138644: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:08.692253: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:09.379370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:10.168003: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:11.135308: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,76]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 03:30:12.525048: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [12,98]
# 	 [[{{node Placeholder/_2}}]]
# 758/758 [==============================] - 2604s 3s/step - loss: 0.4708 - val_loss: 0.3051 - accuracy: 0.8661
# Epoch 2/7
# 758/758 [==============================] - ETA: 0s - loss: 0.2730
# 2023-11-25 04:11:13.817816: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,48]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:14.717225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:15.459075: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:16.283173: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:17.007629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:17.690035: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:18.418481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:19.254512: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:19.948009: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,34]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:20.595921: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:21.350448: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,29]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:21.899238: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:22.864701: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,73]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:24.316947: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:24.983645: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:25.931503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:26.898254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:27.471572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:28.128837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:28.716515: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:29.753732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:30.537943: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:31.117366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:32.067993: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:32.600702: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:33.225689: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:34.064869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,33]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:34.685151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:35.258454: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:35.926049: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:36.748334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:37.554420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,51]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:38.457453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:39.183545: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:40.085144: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:40.812175: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:41.462164: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,52]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:42.404887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,53]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:43.361753: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 04:11:44.083758: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# ...
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:36:59.866660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:00.416292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:01.081045: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:01.913610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,40]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:02.639160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,44]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:03.466004: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:04.119510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:04.928757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,109]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:06.975228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,42]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:07.751334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,39]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:08.465016: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:09.054367: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:09.803266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:10.478719: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:11.462720: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,72]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:12.734547: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,84]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:14.247006: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:14.945324: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,47]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:15.795481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,67]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:17.013400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,32]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:17.633941: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:18.376727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:18.934878: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:19.658305: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,49]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:20.542124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:21.217489: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,57]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:22.246668: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:23.021234: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,36]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:23.675225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:24.321772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,41]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:25.062760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:25.752729: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:26.522358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,35]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:27.159599: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,46]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:27.989490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:28.555964: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,45]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:29.369160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,31]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:29.929807: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,37]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:30.610617: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,28]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:31.139814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,30]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:31.701350: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,38]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:32.392667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,43]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:33.166568: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,54]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:34.164585: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [16,76]
# 	 [[{{node Placeholder/_2}}]]
# 2023-11-25 05:37:35.528205: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_2' with dtype int64 and shape [12,98]
# 	 [[{{node Placeholder/_2}}]]
# O Kernel falhou ao executar o código na célula atual ou em uma célula anterior. Examine o código nas células para identificar uma possível causa da falha. Clique <a href="https://aka.ms/vscodeJupyterKernelCrash">aqui</a> para obter mais informações. Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.
